# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(40,30),dpi=100) # 前一个参数是图片尺寸，后面的参数是分辨率

# %%
X = range(2, 26, 2)

# %%
X
# Out:
# range(2, 26, 2)

# %%
Y = [12, 23, 24, 25, 26, 32, 37, 35, 26, 27, 19, 10]

# %% [markdown]
# ### 绘制折线图

# %%
plt.plot(X,Y)

# %%
plt.xticks(X)
# Out:
# ([<matplotlib.axis.XTick at 0x21a554a4dd0>,
# ...
#  [Text(2, 0, '2'),
#   Text(4, 0, '4'),
#   Text(6, 0, '6'),
#   Text(8, 0, '8'),
#   Text(10, 0, '10'),
#   Text(12, 0, '12'),
#   Text(14, 0, '14'),
#   Text(16, 0, '16'),
#   Text(18, 0, '18'),
#   Text(20, 0, '20'),
#   Text(22, 0, '22'),
#   Text(24, 0, '24')])

# %%
# plt.savefig("./fig_save.png")   # 保存图片 png是标量图 svg是矢量图

# %%
plt.show()
